# %%
import os
# %pwd
# Out:
# 'c:\\Users\\Prarthana\\Desktop\\projects\\voice-recognition-system\\notebooks'

# %%
os.chdir('../')
# %pwd
# Out:
# 'c:\\Users\\Prarthana\\Desktop\\projects\\voice-recognition-system'

# %%
from IPython.display import Audio
Audio("data/raw/mini_speech_commands/down/f852895b_nohash_1.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
